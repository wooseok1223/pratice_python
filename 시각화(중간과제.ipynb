# %%
import pandas as pd
import matplotlib as mlt
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pandas.plotting import scatter_matrix

final1 = pd.read_csv("C:/pratice/exam(middle)/datas/final_t1.csv",sep=None,encoding='ms949', engine='python')
final1 = final1.drop('Unnamed: 0', 1)
final1_temp = final1.iloc[:,[0,1,2,3,4,13]]
final1_temp = final1_temp.set_index(['key','구명'])
print(final1_temp)

final2= pd.read_csv("C:/pratice/exam(middle)/datas/final_t2.csv",sep=None,encoding='ms949', engine='python')
final2_temp = final2.iloc[:,[0,1,3,4,5,6,7,8]]
final2_temp_gu = final2_temp.groupby(['key','구명']).sum()
print(final2_temp_gu)

test = pd.merge(final1_temp,final2_temp_gu, on = ['구명'],how = "inner")

scatter_matrix(test, figsize=(10, 10));
plt.tight_layout()
plt.show()


print(test.corr())
# Out:
#                    교통량       공시지가 가격  사고 발생건수     자동차대수
# key 구명
# 0   강남구   9.702439e+07  2.444212e+11     3469  215232.0
# 1   강동구   4.158514e+07  9.380711e+10     1371  126528.0
# 2   강북구   2.205417e+07  8.313019e+10     1202   72325.0
# 3   강서구   2.425615e+07  9.035855e+10     1584  186482.0
# 4   관악구   9.567799e+06  1.316291e+11     1251  115564.0
# 5   광진구   5.882772e+07  1.069452e+11     1064   94290.0
# 6   구로구   5.076356e+07  3.513373e+10     1433  129451.0
# 7   금천구   2.354161e+07  4.527353e+10      824   81022.0
# 8   노원구   3.467331e+07  5.812809e+10     1499  144063.0
# 9   도봉구   1.351701e+07  1.086102e+11      944   89465.0
# 10  동대문구  9.804152e+06  1.232330e+11     1718   92689.0
# 11  동작구   1.971319e+07  1.218409e+11     1409  102357.0
# 12  마포구   7.963127e+07  1.854044e+11     1859  110743.0
# 13  서대문구  2.715231e+07  1.282433e+11     1032   80677.0
# 14  서초구   1.249610e+08  1.603523e+11     2361  168412.0
# 15  성동구   6.899234e+07  9.180160e+10     1076   96092.0
# ...

# %%
test.corr()
# Out:
#               교통량   공시지가 가격   사고 발생건수     자동차대수       순수익    시세_재산세    구세_재산세  \
# 교통량      1.000000  0.428806  0.573307  0.304409  0.775570  0.622454  0.642893
# 공시지가 가격  0.428806  1.000000  0.457342  0.167265  0.407242  0.532597  0.482121
# 사고 발생건수  0.573307  0.457342  1.000000  0.763158  0.757946  0.852464  0.857770
# 자동차대수    0.304409  0.167265  0.763158  1.000000  0.481341  0.615540  0.657957
# 순수익      0.775570  0.407242  0.757946  0.481341  1.000000  0.873621  0.893361
# 시세_재산세   0.622454  0.532597  0.852464  0.615540  0.873621  1.000000  0.973212
# 구세_재산세   0.642893  0.482121  0.857770  0.657957  0.893361  0.973212  1.000000
# 어린이      0.130152  0.055615  0.589677  0.941928  0.273916  0.399291  0.453800
# 노인      -0.046765  0.004662  0.505108  0.873443  0.139216  0.288712  0.328681
# 총인구     -0.063987  0.026123  0.505565  0.878368  0.115593  0.287559  0.323547
#
#               어린이        노인       총인구
# 교통량      0.130152 -0.046765 -0.063987
# ...

# %%
final_gu = pd.read_csv("C:/pratice/exam(middle)/datas/final_t1.csv",sep=None,encoding='ms949', engine='python')

# %%
final_gu = final_gu[['구명','교통량']]
final_gu = final_gu.set_index('구명')
final_gu
# Out:
#                교통량
# 구명
# 강남구   9.702439e+07
# 강동구   4.158514e+07
# 강북구   2.205417e+07
# 강서구   2.425615e+07
# 관악구   9.567799e+06
# 광진구   5.882772e+07
# 구로구   5.076356e+07
# 금천구   2.354161e+07
# 노원구   3.467331e+07
# 도봉구   1.351701e+07
# 동대문구  9.804152e+06
# 동작구   1.971319e+07
# 마포구   7.963127e+07
# 서대문구  2.715231e+07
# 서초구   1.249610e+08
# 성동구   6.899234e+07
# 성북구   1.797219e+07
# 송파구   4.944728e+07
# 양천구   4.762453e+07
# 영등포구  8.118868e+07
# 용산구   3.301965e+07
# 은평구   2.037916e+07
# 종로구   6.943273e+07
# 중구    6.452106e+07
# 중랑구   3.104701e+07

# %%
final_dong = pd.read_csv("C:/pratice/exam(middle)/datas/final_t2.csv",sep=None,encoding='ms949', engine='python')
final_dong = final_dong.drop('key',1)
final_dong = final_dong.drop('구명',1)
final_dong = final_dong.iloc[:,[0,6]]
final_dong['동명'] = '태전동'
final_dong
# Out:
#       동명      총인구
# 0    태전동   7790.0
# 1    태전동  13847.0
# 2    태전동  18915.0
# 3    태전동  24044.0
# 4    태전동  22284.0
# 5    태전동  25576.0
# 6    태전동  40144.0
# 7    태전동  21256.0
# 8    태전동  22836.0
# 9    태전동  34689.0
# 10   태전동  15248.0
# 11   태전동  30482.0
# 12   태전동  45439.0
# 13   태전동  16416.0
# 14   태전동      0.0
# 15   태전동  28131.0
# 16   태전동  36839.0
# 17   태전동  36805.0
# 18   태전동  17132.0
# 19   태전동  16588.0
# 20   태전동  24776.0
# 21   태전동  30165.0
# 22   태전동  32918.0
# 23   태전동  27442.0
# 24   태전동   7706.0
# 25   태전동  47150.0
# 26   태전동    309.0
# 27   태전동  28248.0
# 28   태전동  22474.0
# 29   태전동  18017.0
# ..   ...      ...
# 394  태전동   3463.0
# 395  태전동   2933.0
# 396  태전동      0.0
# 397  태전동      0.0
# 398  태전동      0.0
# 399  태전동      0.0
# 400  태전동   9682.0
# 401  태전동      0.0
# 402  태전동   1892.0
# 403  태전동   5651.0
# 404  태전동  12955.0
# 405  태전동   5036.0
# 406  태전동  13369.0
# 407  태전동   5918.0
# 408  태전동  18320.0
# 409  태전동  31775.0
# 410  태전동  26474.0
# 411  태전동      0.0
# ...

# %%
## 우리나라 따기 
import json
import folium

geo_path = 'C:/pratice/exam(middle)/datas/json/test2.json'
geo_str = json.load(open(geo_path, encoding = 'utf-8'))

seoul_map = folium.Map(location = [37.5502,126.982], zoom_start =11)
seoul_map.choropleth(geo_data =  geo_str, data = final_dong, 
columns =  ['동명','총인구'],
key_on = 'properties.name',
highlight = True,
fill_opacity = 0.5, line_opacity = 1,
fill_color = 'PuRd')

# %%
seoul_map.save('seoul_map.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
road_data = pd.read_csv("C:/pratice/exam(middle)/datas/final_road_data.csv",sep=None,encoding='ms949', engine='python')
# road_data = final_dong.drop('key',1)
# road_data = final_dong.drop('구명',1)
road_data = road_data.iloc[:,[2,3]]
road_data
# Out:
#             지점명         교통량
# 0        남산1호터널  10432283.0
# 1   장충단로(장충단공원)   7745094.0
# 2    세종대로(시청역2)   7460350.0
# 3     사직로(사직터널)  10538944.0
# 4  통일로(산골고개정류장)   9612342.0

# %%
## 도로 따기 
import folium

enter_lat = 37.5502
center_lon = 126.982
# generating a couple of random latlongs in the omaha area
lats = np.random.uniform(low=center_lat - .25, high=center_lat + .25, size=(2,))
lons = np.random.uniform(low=center_lon - .25, high=center_lon + .25, size=(2,))

p1 = [37.498114, 127.028450]
p2 = [37.509962, 127.066645]

t1 = [37.479263, 126.901025]
t2 = [37.484882, 126.934928]
t3 = [37.482498, 126.941451]
t4 = [37.481408, 126.952524]
t5 = [37.475278, 126.968917]
t6 = [37.476708, 126.978273]

q1 = [37.555858, 126.992860]
q2 = [37.549725, 126.996454]

a1 = [37.517443, 127.018728]
a2 = [37.484758, 127.033491]
a3 = [37.480127, 127.037782]
a4 = [37.468410, 127.039842]

b1 = [37.459959, 127.028739] #37.459959, 127.028739
b2 = [37.470402, 126.996137] #37.470402, 126.996137 
b3 = [37.469325, 126.957665] #37.469325, 126.957665 
b4 = [37.471805, 126.952699] #37.471805, 126.952699 
b5 = [37.450378, 126.921420] #37.450378, 126.921420
b6 = [37.454224, 126.900089]

seoul_map = folium.Map(location = [enter_lat,center_lon], zoom_start =14)
	
folium.TileLayer('cartodbpositron').add_to(seoul_map)
#--------------------------테헤란로
folium.CircleMarker(p1,popup = '테헤란로',
                    color = '#030705',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(p2,popup = '테헤란로',
                    color = '#030705',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[p1, p2], color='gray').add_to(seoul_map)                          

#---------------------------강남순환로
folium.CircleMarker(t1,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(t2,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t3,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t4,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t5,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t6,popup = '강남순환로',
                    color = '#ff0000',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[t1, t2,t3,t4,t5,t6], color='red').add_to(seoul_map)

#--------------------------남산1호터널
folium.CircleMarker(q1,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(q2,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[q1, q2], color='blue').add_to(seoul_map)

#----------------------------강남대로
folium.CircleMarker(a1,popup = '강남대로',
                    color = '#01f300',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(a2,popup = '강남대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(a3,popup = '강남대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(a4,popup = '강남대로',
                    color = '#01f300',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[a1, a2, a3, a4], color='green').add_to(seoul_map)

#----------------------------강남순환로
folium.CircleMarker(b1,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(b2,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(b3,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b4,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(b5,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b6,popup = '강남순환로',
                    color = '#ffff00',
                    radius = 2).add_to(seoul_map)


folium.PolyLine(locations=[b1, b2, b3, b4, b5 , b6], color='gold').add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_map.save('road.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
final1_1 = pd.read_csv("C:/pratice/exam(middle)/datas/final_t1.csv",sep=None,encoding='ms949', engine='python')
final1_1 = final1_1.drop('key', 1)
final1_temp = final1.iloc[:,[1,4,5]]
final1_temp = final1_temp.set_index('구명')
final1_temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-ed1b1586ccb2> in <module>
#       1 final1_1 = pd.read_csv("C:/pratice/exam(middle)/datas/final_t1.csv",sep=None,encoding='ms949', engine='python')
#       2 final1_1 = final1_1.drop('key', 1)
# ----> 3 final1_temp = final1.iloc[:,[1,4,5]]
#       4 final1_temp = final1_temp.set_index('구명')
#       5 final1_temp
#
# NameError: name 'final1' is not defined

# %%
test
# Out:
#                교통량       공시지가 가격  사고 발생건수     자동차대수         순수익    시세_재산세  \
# 구명
# 강남구   9.702439e+07  2.444212e+11     3469  215232.0  1423582.17  326151.0
# 강동구   4.158514e+07  9.380711e+10     1371  126528.0   131273.36   70097.0
# 강북구   2.205417e+07  8.313019e+10     1202   72325.0    24585.06   24992.0
# 강서구   2.425615e+07  9.035855e+10     1584  186482.0   317427.94   62721.0
# 관악구   9.567799e+06  1.316291e+11     1251  115564.0    64665.93   45256.0
# 광진구   5.882772e+07  1.069452e+11     1064   94290.0   108771.61   47133.0
# 구로구   5.076356e+07  3.513373e+10     1433  129451.0   131048.84       0.0
# 금천구   2.354161e+07  4.527353e+10      824   81022.0    44477.34   31322.0
# 노원구   3.467331e+07  5.812809e+10     1499  144063.0    50538.14   36350.0
# 도봉구   1.351701e+07  1.086102e+11      944   89465.0    36622.42   27087.0
# 동대문구  9.804152e+06  1.232330e+11     1718   92689.0   101691.16   45474.0
# 동작구   1.971319e+07  1.218409e+11     1409  102357.0   132956.46   46482.0
# ...

# %%
plt.figure(figsize  = (8,6))
plt.scatter(test['교통량'], test['사고 발생건수'])

plt.show()

# %%
import seaborn as sns
import matplotlib as mlt
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pandas.plotting import scatter_matrix

fm.get_fontconfig_fonts()
font_location = 'C:\\WINDOWS\\Fonts\\ng.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
mlt.rc('font', family=font_name)

# %%
plt.rcParams["figure.figsize"] = (25,20)
sns.barplot(x=test.index, y=test['사고 발생건수'], hue= test["총인구"], data=test)
plt.title("구별, 사고발생 건수")
plt.show()

# %%
plt.rcParams["figure.figsize"] = (25,20)
sns.barplot(x=test.index, y=test['사고 발생건수'], hue= test["공시지가 가격"], data=test)
plt.title("구별, 사고발생 건수")
plt.show()
# Out:
#   File "<ipython-input-54-d01f6926f891>", line 2
#     sns.barplot(x=test.index, y=test['사고 발생건수'], hue= test["공시지가 가격"],test["총인구"], data=test)
#                                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
import pandas as pd
import matplotlib as mlt
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pandas.plotting import scatter_matrix

fm.get_fontconfig_fonts()
font_location = 'C:\\WINDOWS\\Fonts\\ng.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
mlt.rc('font', family=font_name)

# %% [markdown]
# # 남산1호터널

# %%
data = pd.read_csv("C:/pratice/exam(middle)/datas/testst.csv" ,encoding = 'ms949')
a = data[(data['구명'] == '중구') & (data['지점명'] == '남산1호터널')]
tt = pd.DataFrame(a)
tt.sort_values(by = '교통량',inplace = True,ascending=False)
data_set = tt.iloc[:,[0,1,3]]
data_set = data_set.groupby(['구명','지점명']).sum()
data_set.reset_index(['구명','지점명'],inplace = True)
data_set
# Out:
#    구명     지점명         교통량
# 0  중구  남산1호터널  10432283.0

# %%
a = pd.read_csv("C:/pratice/exam(middle)/datas/데이터 분석/남산1호터널.csv",sep=None,encoding='ms949', engine='python')
a = a.drop('Unnamed: 0', 1)
data1 = a.drop('key', 1)

data1 = data1.groupby(['구명']).sum()
data1.reset_index(['구명'],inplace = True)
data1

dd = pd.merge(data_set,data1, on = '구명')
dd
# Out:
#    구명     지점명         교통량       순수익  시세_재산세  구세_재산세    어린이      노인      총인구
# 0  중구  남산1호터널  10432283.0  42291.35  5867.0  5108.0  690.0  1815.0  10687.0

# %% [markdown]
# # 장충단로

# %%
data = pd.read_csv("C:/pratice/exam(middle)/datas/testst.csv" ,encoding = 'ms949')
a = data[(data['구명'] == '중구') & (data['지점명'] == '장충단로(장충단공원)')]
tt = pd.DataFrame(a)
tt.sort_values(by = '교통량',inplace = True,ascending=False)
data_set2 = tt.iloc[:,[0,1,3]]
data_set2 = data_set2.groupby(['구명','지점명']).sum()
data_set2.reset_index(['구명','지점명'],inplace = True)
data_set2
# Out:
#    구명          지점명        교통량
# 0  중구  장충단로(장충단공원)  7745094.0

# %%
a = pd.read_csv("C:/pratice/exam(middle)/datas/데이터 분석/장충대로.csv",sep=None,encoding='ms949', engine='python')
a = a.drop('Unnamed: 0', 1)
data2 = a.drop('key', 1)

data2 = data2.groupby(['구명']).sum()
data2.reset_index(['구명'],inplace = True)
data2

dd2 = pd.merge(data_set2,data2, on = '구명')
dd2
# Out:
#    구명          지점명        교통량       순수익  시세_재산세  구세_재산세    어린이      노인  \
# 0  중구  장충단로(장충단공원)  7745094.0  62602.33  9413.0  8002.0  672.0  1959.0
#
#        총인구
# 0  11695.0

# %% [markdown]
# # 세종대로(시청역2)

# %%
data = pd.read_csv("C:/pratice/exam(middle)/datas/testst.csv" ,encoding = 'ms949')
a = data[(data['구명'] == '중구') & (data['지점명'] == '세종대로(시청역2)')]
tt = pd.DataFrame(a)
tt.sort_values(by = '교통량',inplace = True,ascending=False)
data_set3 = tt.iloc[:,[0,1,3]]
data_set3 = data_set3.groupby(['구명','지점명']).sum()
data_set3.reset_index(['구명','지점명'],inplace = True)
data_set3
# Out:
#    구명         지점명        교통량
# 0  중구  세종대로(시청역2)  7460350.0

# %%
a = pd.read_csv("C:/pratice/exam(middle)/datas/데이터 분석/세종대로.csv",sep=None,encoding='ms949', engine='python')
a = a.drop('Unnamed: 0', 1)
data3 = a.drop('key', 1)

data3 = data3.groupby(['구명']).sum()
data3.reset_index(['구명'],inplace = True)
data3

dd3 = pd.merge(data_set3,data3, on = '구명')
dd3
# Out:
#    구명         지점명        교통량        순수익   시세_재산세   구세_재산세    어린이      노인  \
# 0  중구  세종대로(시청역2)  7460350.0  603535.25  55730.0  51380.0  962.0  2554.0
#
#        총인구
# 0  12314.0

# %% [markdown]
# # 사직로(사직터널)

# %%
data = pd.read_csv("C:/pratice/exam(middle)/datas/testst.csv" ,encoding = 'ms949')
a = data[(data['구명'] == '종로구') & (data['지점명'] == '사직로(사직터널)')]
tt = pd.DataFrame(a)
tt.sort_values(by = '교통량',inplace = True,ascending=False)
data_set4 = tt.iloc[:,[0,1,3]]
data_set4 = data_set4.groupby(['구명','지점명']).sum()
data_set4.reset_index(['구명','지점명'],inplace = True)
data_set4
# Out:
#     구명        지점명         교통량
# 0  종로구  사직로(사직터널)  10538944.0

# %%
a = pd.read_csv("C:/pratice/exam(middle)/datas/데이터 분석/사직로.csv",sep=None,encoding='ms949', engine='python')
a = a.drop('Unnamed: 0', 1)
data4 = a.drop('key', 1)

data4 = data4.groupby(['구명']).sum()
data4.reset_index(['구명'],inplace = True)
data4

dd4 = pd.merge(data_set4,data4, on = '구명')
dd4
# Out:
#     구명        지점명         교통량       순수익   시세_재산세   구세_재산세     어린이      노인  \
# 0  종로구  사직로(사직터널)  10538944.0  40838.36  14857.0  15077.0  3590.0  6839.0
#
#        총인구
# 0  28878.0

# %% [markdown]
# # 통일로(산골고개정류장)

# %%
data = pd.read_csv("C:/pratice/exam(middle)/datas/testst.csv" ,encoding = 'ms949')
a = data[(data['구명'] == '종로구') & (data['지점명'] == '통일로(산골고개정류장)')]
tt = pd.DataFrame(a)
tt.sort_values(by = '교통량',inplace = True,ascending=False)
data_set5 = tt.iloc[:,[0,1,3]]
data_set5 = data_set5.groupby(['구명','지점명']).sum()
data_set5.reset_index(['구명','지점명'],inplace = True)
data_set5
# Out:
#     구명           지점명        교통량
# 0  종로구  통일로(산골고개정류장)  9612342.0

# %%
b = pd.read_csv("C:/pratice/exam(middle)/datas/데이터 분석/통일로.csv",sep=None,encoding='ms949', engine='python')
b = b.drop('Unnamed: 0', 1)
data5 = b.drop('key', 1)

data5 = data5.groupby(['구명']).sum()
data5.reset_index(['구명'],inplace = True)
data5

dd5 = pd.merge(data_set5,data5, on = '구명')
dd5
# Out:
#     구명           지점명        교통량      순수익  시세_재산세  구세_재산세     어린이      노인  \
# 0  종로구  통일로(산골고개정류장)  9612342.0  3987.28  2985.0  3029.0  2526.0  4474.0
#
#        총인구
# 0  19077.0

# %% [markdown]
# # merge

# %%
aaa = pd.concat([dd,dd2,dd3,dd4,dd5])
aaa.to_csv("C:/pratice/exam(middle)/datas/final_road_data.csv",na_rep='NaN',encoding = 'ms949')
aaa
# Out:
#     구명           지점명         교통량        순수익   시세_재산세   구세_재산세     어린이      노인  \
# 0   중구        남산1호터널  10432283.0   42291.35   5867.0   5108.0   690.0  1815.0
# 0   중구   장충단로(장충단공원)   7745094.0   62602.33   9413.0   8002.0   672.0  1959.0
# 0   중구    세종대로(시청역2)   7460350.0  603535.25  55730.0  51380.0   962.0  2554.0
# 0  종로구     사직로(사직터널)  10538944.0   40838.36  14857.0  15077.0  3590.0  6839.0
# 0  종로구  통일로(산골고개정류장)   9612342.0    3987.28   2985.0   3029.0  2526.0  4474.0
#
#        총인구
# 0  10687.0
# 0  11695.0
# 0  12314.0
# 0  28878.0
# 0  19077.0

# %%
scatter_matrix(data1, figsize=(10, 10));
plt.tight_layout()
plt.show()


data1.corr()

# %%
import googlemaps
import pandas as pd
from selenium import webdriver
import time
import re
from selenium.webdriver.common.keys import Keys

pd.set_option('mode.chained_assignment', None)
#데이터 합치기
names = range(1,6)
data = []
for name in names:
    path = "C:/pratice/exam(middle)/datas/교통량/교통량%d.csv" %name
    frame = pd.read_csv(path, sep=None,encoding='utf-8',engine='python')

    data.append(frame)

traffic_value = pd.concat(data,sort = False, verify_integrity=False,  ignore_index=False, join = 'outer')

traffic_value['교통량'] = traffic_value.iloc[:,5:].sum(axis = 1)
traffic_value = traffic_value.iloc[:,[2,5,31]]

traffic_value = traffic_value.set_index(['지점명','구분'])
traffic_value = traffic_value.groupby(["지점명","구분"]).sum()

traffic_value.reset_index(level = ['지점명','구분'],inplace = True)

# 구글 api주소 받기
g_key = 'AIzaSyD0RwWgzRYYFCO6J8hViwugajDvHYV3FJA'
gmaps = googlemaps.Client(key=g_key)
gu_list = []

for road in traffic_value['지점명']:
    tmp = gmaps.geocode(road, language='ko')

    try:
        new_tmp = tmp[0]['formatted_address'].split(' ')
        if (new_tmp[0] == '대한민국') and (new_tmp[1] == '서울특별시') and \
                (new_tmp[2][-1] == '구'):
            gu = new_tmp[2]
            gu_list.append(gu)
        else:
            gu_list.append('')
    except:
        gu_list.append('')

## 구, 지점명 데이터프레임 만들기
gu_dataframe = pd.DataFrame({'지점명': traffic_value['지점명'], '구': gu_list},
                            columns=['구', '지점명'])

## 공백인 것 뽑아내기
crawling_list = list(gu_dataframe[gu_dataframe['구'] == '']['지점명'])

## 괄호 안에  것만 빼내자

crawling_clean_list = []
for word in crawling_list:
    in_bracket = re.sub('.*\(', '', word)
    in_bracket = re.sub('\)', '', in_bracket)
    crawling_clean_list.append(in_bracket)
crawling_clean_list

## 크롬 드라이버 가져오기
driver = webdriver.Chrome(executable_path='C:/pratice/chromedriver_win32/chromedriver')
## 다음맵에 접속
driver.get('https://map.kakao.com/')
## 닫기 클릭
driver.find_element_by_xpath('/html/body/div[10]/div/div[2]/a').click()
## 검색창에 접근
element = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
gu_list_crawling = []
for word in crawling_clean_list:
    ## 글자 넣고
    element.send_keys(word)
    ## 검색클릭
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)
    ## 1초기다렸다가
    time.sleep(0.5)
    ## 글자에 접근
    try:
        juso_element = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[2]/p[1]')
        juso = juso_element.text.split(' ')
        gu_list_crawling.append(juso[1])
    except:
        gu_list_crawling.append('')

    element.clear()

## 크롤링한 것을 데이터프레임에 넣기
crawling_dataframe = pd.DataFrame({'구': gu_list_crawling, '지점명': crawling_list})

#구글 api와 크롤링한 것 결합
crawling_dataframe_dup = crawling_dataframe.drop_duplicates(['지점명'])
crawling_dataframe_dup = crawling_dataframe_dup.reset_index()
del crawling_dataframe_dup['index']
for i in range(len(crawling_dataframe_dup['지점명'])):
    for j in range(len(gu_dataframe['지점명'])):
        if crawling_dataframe_dup['지점명'][i] == gu_dataframe['지점명'][j]:
            gu_dataframe['구'][j] = crawling_dataframe_dup['구'][i]

## 구가 아닌 것 제거
for i in range(len(gu_dataframe['구']) - 1):
    try:
        if gu_dataframe['구'][i][-1] != '구':
            gu_dataframe = gu_dataframe.drop(i)
    except:
        gu_dataframe = gu_dataframe.drop(i)

## 겹치는 것 제거
gu_dataframe = gu_dataframe.drop_duplicates(['지점명'])

## 인덱스 다시 맞추기
gu_dataframe = gu_dataframe.reset_index()
gu_dataframe = gu_dataframe.drop('index', axis=1)

traffic_value = pd.merge(traffic_value, gu_dataframe, on='지점명')
traffic_value = traffic_value.sort_index()


traffic_value.sort_values(by = '구',inplace = True)
traffic_value.rename(columns = {'구' : '구명'}, inplace = True)

traffic_value = traffic_value.set_index(['구명'])
print(traffic_value)

traffic_value.to_csv("C:/pratice/exam(middle)/datas/testst.csv",na_rep='NaN',encoding = 'ms949')
# Out:
#                   지점명                 구분         교통량
# 구명
# 강남구       남부순환로(수서IC)         수서IC->탄천1교   6839586.0
# 강남구         테헤란로(선릉역)        선릉역->포스코사거리   4211200.0
# 강남구       남부순환로(수서IC)         탄천1교->수서IC   6257017.0
# 강남구              한남대교     한남대교남단->한남대교북단  14934466.0
# 강남구              한남대교     한남대교북단->한남대교남단  14547353.0
# 강남구       헌릉로(세곡동사거리)       내곡IC->세곡동사거리   3999879.0
# 강남구         언주로(매봉터널)       영동세브란스->매봉터널   3821860.0
# 강남구         언주로(매봉터널)       매봉터널->영동세브란스   4482993.0
# 강남구         테헤란로(선릉역)        포스코사거리->선릉역   5985166.0
# 강남구             강남순환로        관악IC->금천요금소   5295143.0
# 강남구             강남순환로        금천요금소->관악IC   5471959.0
# 강남구      밤고개로(세곡동사거리)   세곡동사거리->밤고개로성남시계   2558272.0
# 강남구      밤고개로(세곡동사거리)   밤고개로성남시계->세곡동사거리   2847488.0
# 강남구       헌릉로(세곡동사거리)       세곡동사거리->내곡IC   4842889.0
# 강남구         강남대로(신사역)           논현역->신사역   5668132.0
# 강남구         강남대로(신사역)           신사역->논현역   5260991.0
# 강동구       올림픽대로(강일IC)       암사대교남단->강일IC  13812513.0
# ...

# %%
import folium
import numpy as np
import pandas as pd
from collections import namedtuple

# using omaha coordinates 
center_lat = 41.257160
center_lon = -95.995102

# generating a couple of random latlongs in the omaha area
lats = np.random.uniform(low=center_lat - .25, high=center_lat +    .25, size=(2,))
lons = np.random.uniform(low=center_lon - .25, high=center_lon + .25, size=(2,))
p1 = [lats[0], lons[0]]
p2 = [lats[1], lons[1]]

some_map = folium.Map(location=[center_lat, center_lon], zoom_start=10)
folium.Marker(location=p1, icon=folium.Icon(color='green')).add_to(some_map)
folium.Marker(location=p2, icon=folium.Icon(color='red')).add_to(some_map)
folium.PolyLine(locations=[p1, p2], color='blue').add_to(some_map)

some_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

enter_lat = 37.573174
center_lon = 126.978728
# generating a couple of random latlongs in the omaha area
lats = np.random.uniform(low=center_lat - .25, high=center_lat + .25, size=(2,))
lons = np.random.uniform(low=center_lon - .25, high=center_lon + .25, size=(2,))
p1 = [37.596209, 126.939275]
p2 = [37.562687, 126.969209]
t1 = [37.569067, 127.009734]
t2 = [37.551309, 127.000550]
q1 = [37.555858, 126.992860]
q2 = [37.549725, 126.996454]
a1 = [37.568692, 126.977009]
a2 = [37.565052, 126.977116]
a3 = [37.560783, 126.975722]
a4 = [37.557177, 126.972524]
b1 = [37.572401, 126.960921]
b2 = [37.572486, 126.963882]
b3 = [37.573973, 126.965694]
b4 = [37.574373, 126.967153]
b5 = [37.576006, 126.969504]
b6 = [37.575836, 126.974032]

seoul_map = folium.Map(location = [enter_lat,center_lon], zoom_start =14)
	
folium.TileLayer('cartodbpositron').add_to(seoul_map)
#--------------------------통일로
folium.CircleMarker(p1,popup = '통일로',
                    color = '#030705',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(p2,popup = '통일로',
                    color = '#030705',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[p1, p2], color='gray').add_to(seoul_map)                          

#---------------------------장충단로
folium.CircleMarker(t1,popup = '장충단로',
                    color = '#ff0000',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(t2,popup = '장충단로',
                    color = '#ff0000',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[t1, t2], color='red').add_to(seoul_map)

#--------------------------남산1호터널
folium.CircleMarker(q1,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(q2,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[q1, q2], color='blue').add_to(seoul_map)

#----------------------------세종대로
folium.CircleMarker(a1,popup = '세종대로',
                    color = '#01f300',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(a2,popup = '세종대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(a3,popup = '세종대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(a4,popup = '세종대로',
                    color = '#01f300',
                    radius = 2).add_to(seoul_map)

folium.PolyLine(locations=[a1, a2, a3, a4], color='green').add_to(seoul_map)

#----------------------------사직로
folium.CircleMarker(b1,popup = '사직로',
                    color = '#ffff00',
                    radius = 2).add_to(seoul_map)                         
folium.CircleMarker(b2,popup = '사직로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(b3,popup = '사직로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b4,popup = '사직로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(b5,popup = '사직로',
                    color = '#ffff00',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b6,popup = '사직로',
                    color = '#ffff00',
                    radius = 2).add_to(seoul_map)


folium.PolyLine(locations=[b1, b2, b3, b4, b5 , b6], color='gold').add_to(seoul_map)

seoul_map

# %%
index = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/index.csv",sep=None,encoding='ms949', engine='python')
index
# Out:
#       동명     도로명
# 0   개포4동    강남대로
# 1   논현1동    강남대로
# 2   도곡1동    강남대로
# 3   도곡2동    강남대로
# 4   역삼1동    강남대로
# 5   반포1동    강남대로
# 6   서초2동    강남대로
# 7   서초4동    강남대로
# 8   양재1동    강남대로
# 9   양재2동    강남대로
# 10  낙성대동   강남순환로
# 11   남현동   강남순환로
# 12   대학동   강남순환로
# 13   삼성동   강남순환로
# 14   서림동   강남순환로
# 15  시흥2동   강남순환로
# 16  시흥3동   강남순환로
# 17  시흥5동   강남순환로
# 18  방배2동   강남순환로
# 19  방배3동   강남순환로
# 20  양재1동   강남순환로
# 21  낙성대동   남부순환로
# 22   미성동   남부순환로
# 23   서원동   남부순환로
# 24   신림동   남부순환로
# 25   신원동   남부순환로
# 26   은천동   남부순환로
# 27   청룡동   남부순환로
# 28   행운동   남부순환로
# 29   장충동  남산1호터널
# 30    필동  남산1호터널
# 31  논현1동    테헤란로
# 32  논현2동    테헤란로
# 33  대치2동    테헤란로
# 34  대치4동    테헤란로
# 35  삼성1동    테헤란로
# 36  삼성2동    테헤란로
# 37  역삼1동    테헤란로

# %%
index = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/index.csv",sep=None,encoding='ms949', engine='python')
data1 = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/강남대로.csv",sep=None,encoding='ms949', engine='python') #정부공공데이터:encoding="euc-kr
data2 = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/강남순환로.csv",sep=None,encoding='ms949', engine='python') #정부공공데이터:encoding="euc-kr
data3 = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/남부순환로.csv",sep=None,encoding='ms949',engine = 'python') #정부공공데이터:encoding="euc-kr
data4 = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/남산1호터널.csv",sep=None,encoding='ms949',engine = 'python') #정부공공데이터:encoding="euc-kr
data5 = pd.read_csv("C:/pratice/exam(middle)/datas/kfc/테헤란로.csv",sep=None,encoding='ms949',engine = 'python') #정부공공데이터:encoding="euc-kr
data = pd.concat([data1, data2, data3, data4, data5])
data["어린이비율"] = data["어린이"]/data["총인구"]*100
data["노인비율"] = data["노인"]/data["총인구"]*100
data["재산세_평균"] = data["시세_재산세"]+data["구세_재산세"]/2
data = data.groupby([data.동명]).mean()

data["어린이비율_qcut"] = pd.qcut(data.어린이비율, 5, labels=["5","4","3", "2", "1"])
data["노인비율_qcut"] = pd.qcut(data.어린이비율, 5, labels=["5","4","3", "2", "1"])
data["재산세평균_qcut"] = pd.qcut(data.어린이비율, 5, labels=["1", "2", "3","4","5"])
data["어린이비율_qcut"] =data["어린이비율_qcut"].astype('float')
data["노인비율_qcut"]  = data["노인비율_qcut"].astype('float')
data["재산세평균_qcut"]=data["재산세평균_qcut"].astype('float')
data["sum"] =data["어린이비율_qcut"]+data["노인비율_qcut"]+data["재산세평균_qcut"] 
data.sort_values(by='sum')

datap = pd.merge(index, data, on="동명")
datap = datap.drop('Unnamed: 0',1)
datap = datap.drop('key',1)
datap
# Out:
#       동명     도로명        순수익   시세_재산세   구세_재산세     어린이       노인      총인구  \
# 0   개포4동    강남대로    8768.07   4750.0   3601.0  2049.0   3369.0  18915.0
# 1   논현1동    강남대로   40107.21  16025.0  10166.0  1289.0   3074.0  24044.0
# 2   논현1동    테헤란로   40107.21  16025.0  10166.0  1289.0   3074.0  24044.0
# 3   도곡1동    강남대로   35053.47   8442.0   5585.0  3061.0   4737.0  22836.0
# 4   도곡2동    강남대로  133613.62  20849.0  12238.0  5209.0   7881.0  34689.0
# 5   역삼1동    강남대로  104173.65  41911.0  24896.0  1862.0   4086.0  36839.0
# 6   역삼1동    테헤란로  104173.65  41911.0  24896.0  1862.0   4086.0  36839.0
# 7   반포1동    강남대로   25783.21  13688.0   9372.0  4937.0   6874.0  32094.0
# 8   서초2동    강남대로  307127.33  19022.0  13074.0  2355.0   3632.0  18492.0
# 9   서초4동    강남대로  262578.77  20130.0  14058.0  5412.0   7866.0  31803.0
# 10  양재1동    강남대로   51434.89   8880.0   5684.0  7415.0  11204.0  46706.0
# 11  양재1동   강남순환로   51434.89   8880.0   5684.0  7415.0  11204.0  46706.0
# ...

# %%
## 우리나라 따기 
import json
import folium
import numpy as np

center_lat = 37.508468
center_lon = 126.990721
# generating a couple of random latlongs in the omaha area
lats = np.random.uniform(low=center_lat - .25, high=center_lat + .25, size=(2,))
lons = np.random.uniform(low=center_lon - .25, high=center_lon + .25, size=(2,))

p1 = [37.498114, 127.028450]
p2 = [37.509962, 127.066645]

t1 = [37.479263, 126.901025]
t2 = [37.484882, 126.934928]
t3 = [37.482498, 126.941451]
t4 = [37.481408, 126.952524]
t5 = [37.475278, 126.968917]
t6 = [37.476708, 126.978273]

q1 = [37.555858, 126.992860]
q2 = [37.549725, 126.996454]

a1 = [37.517443, 127.018728]
a2 = [37.484758, 127.033491]
a3 = [37.480127, 127.037782]
a4 = [37.468410, 127.039842]

b1 = [37.459959, 127.028739] #37.459959, 127.028739
b2 = [37.470402, 126.996137] #37.470402, 126.996137 
b3 = [37.469325, 126.957665] #37.469325, 126.957665 
b4 = [37.471805, 126.952699] #37.471805, 126.952699 
b5 = [37.450378, 126.921420] #37.450378, 126.921420
b6 = [37.454224, 126.900089]


geo_path = 'C:/pratice/exam(middle)/datas/json/test2.json'
geo_str = json.load(open(geo_path, encoding = 'utf-8-sig'))

seoul_map = folium.Map(location = [center_lat,center_lon], zoom_start =12)
seoul_map.choropleth(geo_data =  geo_str, data = datap, 
columns =  ['동명','sum'],
key_on = 'properties.name',
highlight = True,
fill_opacity = 0.5, line_opacity = 1,
fill_color = 'PuRd')
folium.TileLayer('cartodbpositron').add_to(seoul_map)
#--------------------------테헤란로
folium.CircleMarker(p1,popup = '테헤란로',
                    color = '#030705',
                    radius = 5).add_to(seoul_map)                         
folium.CircleMarker(p2,popup = '테헤란로',
                    color = '#030705',
                    radius = 5).add_to(seoul_map)

folium.PolyLine(locations=[p1, p2], popup = '테헤란로',color='gray').add_to(seoul_map)                          

#---------------------------남부순환로
folium.CircleMarker(t1,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 5).add_to(seoul_map)                         
folium.CircleMarker(t2,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t3,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t4,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t5,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(t6,popup = '남부순환로',
                    color = '#ff0000',
                    radius = 5).add_to(seoul_map)

folium.PolyLine(locations=[t1, t2,t3,t4,t5,t6],popup = '남부순환로', color='red').add_to(seoul_map)

#--------------------------남산1호터널
folium.CircleMarker(q1,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 5).add_to(seoul_map)                         
folium.CircleMarker(q2,popup = '남산1호터널',
                    color = '#0001fb',
                    radius = 5).add_to(seoul_map)

folium.PolyLine(locations=[q1, q2], popup = '남산1호터널',color='blue').add_to(seoul_map)

#----------------------------강남대로
folium.CircleMarker(a1,popup = '강남대로',
                    color = '#01f300',
                    radius = 5).add_to(seoul_map)                         
folium.CircleMarker(a2,popup = '강남대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(a3,popup = '강남대로',
                    color = '#01f300',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(a4,popup = '강남대로',
                    color = '#01f300',
                    radius = 5).add_to(seoul_map)

folium.PolyLine(locations=[a1, a2, a3, a4],popup = '강남대로', color='green').add_to(seoul_map)

#----------------------------강남순환로
folium.CircleMarker(b1,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius = 5).add_to(seoul_map)                         
folium.CircleMarker(b2,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius = 0.1).add_to(seoul_map)

folium.CircleMarker(b3,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b4,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius = 0.1).add_to(seoul_map)
folium.CircleMarker(b5,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius = 0.1).add_to(seoul_map)                         
folium.CircleMarker(b6,popup = '강남순환로',
                    color = '#ffff00',
                    fill_color ='gold',
                    radius =5).add_to(seoul_map)


folium.PolyLine(locations=[b1, b2, b3, b4, b5 , b6],popup = '강남순환로', color='gold').add_to(seoul_map)

seoul_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b70090878fb6> in <module>
#      40
#      41 seoul_map = folium.Map(location = [center_lat,center_lon], zoom_start =12)
# ---> 42 seoul_map.choropleth(geo_data =  geo_str, data = datap,
#      43 columns =  ['동명','sum'],
#      44 key_on = 'properties.name',
#
# NameError: name 'datap' is not defined

# %%
seoul_map.save('map.html')
seoul_map
